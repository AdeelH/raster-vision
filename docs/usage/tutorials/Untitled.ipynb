# %%
# !mamba install -c conda-forge h5py h5netcdf netcdf4 -y
# Out:
# Looking for: ['h5py', 'h5netcdf', 'netcdf4']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
#
# Pinned packages:
#   - python 3.10.*
#
#
# warning  libmamba Package tarball '/opt/conda/pkgs/libgoogle-cloud-2.12.0-h19a6dae_3.conda' is invalid
# warning  libmamba Package tarball '/opt/conda/pkgs/tiledb-2.16.3-h8c794c1_3.conda' is invalid
# warning  libmamba Package tarball '/opt/conda/pkgs/libspatialite-5.0.1-h090f1da_29.conda' is invalid
# warning  libmamba Package tarball '/opt/conda/pkgs/libgdal-3.6.4-h0da8fbe_19.conda' is invalid
# Transaction
#
#   Prefix: /opt/conda
#
#   Updating specs:
#
#    - h5py
#    - h5netcdf
#    - netcdf4
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                Version  Build                    Channel           Size
# ───────────────────────────────────────────────────────────────────────────────────
#   Install:
# ...

# %%
import xarray as xr

# %%
path = 'MODIS-AQUA-C061_AOD-and-DOD-V1-GRID_RESOLUTION_0.1-2017/2017/GRID_RESOLUTION_0.1/MODIS-AQUA-C061_AOD-and-DOD-V1-GRID_RESOLUTION_0.1-20170101.nc'
xr.open_dataset(path, drop_variables=['Latitude', 'Longitude'])
# Out:
# <xarray.Dataset>
# Dimensions:                                                (Latitude: 1800,
#                                                             Longitude: 3600,
#                                                             Time: 1)
# Coordinates:
#   * Time                                                   (Time) object 2017...
# Dimensions without coordinates: Latitude, Longitude
# Data variables:
#     Aod_550_dark_target_deep_blue_combined                 (Latitude, Longitude) float32 ...
#     Modis-total-dust-optical-depth-at-550nm                (Latitude, Longitude) float32 ...
#     Modis-fine-dust-optical-depth-at-550nm                 (Latitude, Longitude) float32 ...
#     Modis-coarse-dust-optical-depth-at-550nm               (Latitude, Longitude) float32 ...
#     Aod_550_dark_target_deep_blue_combined_algorithm_flag  (Latitude, Longitude) float32 ...
#     Lsf                                                    (Latitude, Longitude) float32 ...
# ...
